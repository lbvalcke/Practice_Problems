# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the countSwaps function below.
def countSwaps(a):
    swaps = 0 
    for i in range(len(a)):
        for j in range(len(a)-1):
            if a[j] > a[j+1]:
                a[j],a[j+1]=a[j+1],a[j]
                swaps += 1
    print('Array is sorted in ' + str(swaps) + ' swaps\n')
    print('First Element: ' + str(a[0]) + '\n')
    print('Last Element: ' + str(a[len(a)-1])+ '\n')
    
    
if __name__ == '__main__':
    n = int(input())

    a = list(map(int, input().rstrip().split()))

    countSwaps(a)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the maximumToys function below.
def maximumToys(prices, k):
    spend = 0
    for index in range(len(prices)):
        
        

if __name__ == '__main__':
#    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nk = input().split()

    n = int(nk[0])

    k = int(nk[1])

    prices = list(map(int, input().rstrip().split()))

    result = maximumToys(prices, k)

#    fptr.write(str(result) + '\n')

#    fptr.close()

# %%
# Python program for implementation of heap Sort 
  
# To heapify subtree rooted at index i. 
# n is size of heap 
def heapify(arr, n, i): 
    largest = i # Initialize largest as root 
    print(largest)
    l = 2 * i + 1     # left = 2*i + 1 
    r = 2 * i + 2     # right = 2*i + 2 
    print(l, r)
    # See if left child of root exists and is 
    # greater than root 
    if l < n and arr[i] < arr[l]: 
        largest = l
        print(largest)
  
    # See if right child of root exists and is 
    # greater than root 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
        print(largest)
  
    # Change root, if needed 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i]
        print(arr[i],arr[largest])# swap 
  
        # Heapify the root. 
        heapify(arr, n, largest) 
  
# The main function to sort an array of given size 
def heapSort(arr): 
    n = len(arr) 
  
    # Build a maxheap. 
    for i in range(n, -1, -1): 
        heapify(arr, n, i) 
  
    # One by one extract elements 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i] # swap 
        heapify(arr, i, 0) 
  
# Driver code to test above 
arr = [ 12, 11, 13, 5, 6, 7] 
heapSort(arr) 
n = len(arr) 
print ("Sorted array is") 
for i in range(n): 
    print ("%d" %arr[i]), 
# This code is contributed by Mohit Kumra

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the maximumToys function below.
def maximumToys(prices, k):
    def mergeSort(prices):
        if len(prices)>1:
            mid = len(prices) // 2            
            l_prices = prices[:mid]
            r_prices = prices[mid:]
            
            mergeSort(l_prices)
            mergeSort(r_prices)
            
            i = j = k = 0
            while i<len(l_prices) and j<len(r_prices):
                if l_prices[i] < r_prices[j]:
                    prices[k] = l_prices[i]
                    i += 1
                else:
                    prices[k] = r_prices[j]
                    j += 1
                k += 1
                
            while i < len(l_prices): 
                prices[k] = l_prices[i] 
                i+=1
                k+=1
            while j < len(r_prices): 
                prices[k] = r_prices[j] 
                j+=1
                k+=1
        return prices

    prices = mergeSort(prices)
    spend = 0
    toys = 0
    print(prices)
    for price in prices:
        if spend + price <= k:
            spend += price
            toys += 1
        else:
            return toys
                    
    
if __name__ == '__main__':
#    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nk = input().split()

    n = int(nk[0])

    k = int(nk[1])

    prices = list(map(int, input().rstrip().split()))

    result = maximumToys(prices, k)

#    fptr.write(str(result) + '\n')

#    fptr.close()

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# QuickSort Implementation
def quickSort(array, left_index, right_index):
    if len(array[left_index:right_index]) > 2:
        median_index = (left_index + right_index) // 2
        i = left_index
        j = right_index
        while i <= median_index and j >= median_index:
            if array[i] > array[j]:
                array[i],array[j] = array[j],array[i]
            i += 1
            j -= 1

        quickSort(array,left_index,median_index)
        quickSort(array,median_index,right_index)

        for index in range(left_index+1, right_index):
            if array[index - 1] > array[index]:
                array[index - 1],array[index] = array[index],array[index - 1]
    else:
        if array[left_index] > array[right_index]:
            array[left_index],array[right_index]=array[right_index],array[left_index]

    return array
    
def median(sorted_array):
    n = len(sorted_array)
    if n % 2 == 0:
        median_val = (sorted_array[n % 2] + sorted_array[n % 2 - 1]) / 2
    else:
        median_val = sorted_array[n // 2]        
    return median_val
    
def activityNotifications(expenditure, d):
    days = len(expenditure)
    notifications = 0
    if d + 1 > days:
        return 0
    
    else:
        for median_day in range(d, len(expenditure)):
            median_array = expenditure[(median_day - d):median_day]
            temp_expenditure = expenditure[median_day]
         
            sorted_array = quickSort(median_array, 0, len(median_array)-1)
            median_val = median(sorted_array)
            print(sorted_array)
            print(median_val)
            print(temp_expenditure)            
            if temp_expenditure >= median_val * 2:
                notifications += 1
            print(notifications)
        return notifications
    
if __name__ == '__main__':
#    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nd = input().split()

    n = int(nd[0])

    d = int(nd[1])

    expenditure = list(map(int, input().rstrip().split()))

    result = activityNotifications(expenditure, d)

#    fptr.write(str(result) + '\n')

#    fptr.close()

# %%
import math
import os
import random
import re
import sys

# Counting Sort
def countSort(array, n=201):

    return array
    
def median(sorted_array):
    n = len(sorted_array)
    if n % 2 == 0:
        median_val = (sorted_array[n % 2] + sorted_array[n % 2 - 1]) / 2
    else:
        median_val = sorted_array[n // 2]        
    return median_val
    
def activityNotifications(expenditure, d):
    days = len(expenditure)
    notifications = 0
    if d + 1 > days:
        return 0
    
    else:
        for median_day in range(d, len(expenditure)):
            if median_day == d:
                median_array = expenditure[(median_day - d):median_day]
                temp_expenditure = expenditure[median_day]

                sorted_array = countSort(median_array, 0, len(median_array)-1)
                median_val = median(sorted_array)
            else:
                                
            print(sorted_array)
            print(median_val)
            print(temp_expenditure)            
            if temp_expenditure >= median_val * 2:
                notifications += 1
            print(notifications)
        return notifications
    
if __name__ == '__main__':
#    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nd = input().split()

    n = int(nd[0])

    d = int(nd[1])

    expenditure = list(map(int, input().rstrip().split()))

    result = activityNotifications(expenditure, d)

#    fptr.write(str(result) + '\n')

#    fptr.close()
